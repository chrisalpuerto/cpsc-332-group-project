# %% [markdown]
# ## Jupyter Notebook For Our SQL commands
#
# - Decided on using the `jupysql pymysql` dependencies to be able to write SQL commands in side a Jupyter Notebook. This will be better so we can show our SQL command history and output history, as using a regular SQL file will not let us show command or output history, as the history will only be stored in your local terminal history
# - We still can use regular SQL files for practice, but harder to track history compared to doing it here

# %%
# %load_ext sql
import os
from dotenv import load_dotenv
load_dotenv()

print("test")

# %sql mysql+pymysql://root:Csuf_332@localhost:3306/cpsc332_group_project
# %sql SHOW DATABASES;
# Out:
# test
# Connecting to 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 8 rows affected.
# +-----------------------+
# |        Database       |
# +-----------------------+
# |    best_study_spots   |
# | cpsc332_group_project |
# |      fintrack_db      |
# |   information_schema  |
# |         mysql         |
# |   performance_schema  |
# |  study_spots_database |
# |          sys          |
# +-----------------------+

# %%
"""
create.sql test #1

using this to show a better output, as using .sql 
files only shows in terminal.
"""
# %sql CREATE DATABASE IF NOT EXISTS study_spots_database;
# %sql USE study_spots_database;
# %sql SHOW DATABASES;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 1 rows affected.
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 8 rows affected.
# +-----------------------+
# |        Database       |
# +-----------------------+
# |    best_study_spots   |
# | cpsc332_group_project |
# |      fintrack_db      |
# |   information_schema  |
# |         mysql         |
# |   performance_schema  |
# |  study_spots_database |
# |          sys          |
# +-----------------------+

# %%
# %%sql
# SHOW TABLES;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 9 rows affected.
# +--------------------------------+
# | Tables_in_study_spots_database |
# +--------------------------------+
# |            Amenity             |
# |            category            |
# |             Hours              |
# |            Location            |
# |             Photo              |
# |             Review             |
# |       Study_Spot_Amenity       |
# |           StudySpot            |
# |             users              |
# +--------------------------------+

# %%
# %%sql
# ALTER TABLE users
# DROP COLUMN password;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# ++
# ||
# ++
# ++

# %%
# %%sql
# CREATE TABLE users (
#     user_id INT AUTO_INCREMENT PRIMARY KEY,
#     username VARCHAR(50) NOT NULL UNIQUE,
#     email VARCHAR(100) NOT NULL UNIQUE,
#     first_name VARCHAR(50),
#     last_name VARCHAR(50),
#     joinDate TIMESTAMP DEFAULT CURRENT_TIMESTAMP
# );
#
# SHOW TABLES;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 1 rows affected.
# +--------------------------------+
# | Tables_in_study_spots_database |
# +--------------------------------+
# |             users              |
# +--------------------------------+

# %%
# %%sql
# CREATE TABLE category (
#     CategoryID VARCHAR(50) PRIMARY KEY UNIQUE,
#     CategoryName VARCHAR(50) NOT NULL
# );
#
# CREATE TABLE Location (
#     LocationID VARCHAR(50) PRIMARY KEY UNIQUE,
#     StreetAddress VARCHAR(255) NOT NULL,
#     City VARCHAR(100) NOT NULL,
#     State VARCHAR(50) NOT NULL,
#     ZipCode INT CHECK (ZipCode >= 10000 AND ZipCode <= 99999),
#     Latitude DECIMAL(10, 7),
#     Longitude DECIMAL(10, 7)
# );
#
# CREATE TABLE StudySpot (
#     SpotID VARCHAR(50) PRIMARY KEY,
#     spotName VARCHAR(100) NOT NULL,
#     Description TEXT,
#     Website VARCHAR(255),
#     location VARCHAR(255) NOT NULL,
#     phoneNumber VARCHAR(20),
#     PriceLevel FLOAT,
#     CategoryID VARCHAR(50),
#     LocationID VARCHAR(50),
#     FOREIGN KEY (CategoryID) REFERENCES category(CategoryID),
#     FOREIGN KEY (LocationID) REFERENCES Location(LocationID)
# );
#
# SHOW TABLES;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 4 rows affected.
# +--------------------------------+
# | Tables_in_study_spots_database |
# +--------------------------------+
# |            category            |
# |            Location            |
# |           StudySpot            |
# |             users              |
# +--------------------------------+

# %%
# %%sql
# CREATE TABLE Review (
#     ReviewID VARCHAR(50) PRIMARY KEY,
#     UserID INT NOT NULL,
#     SpotID VARCHAR(50) NOT NULL,
#     Rating INT CHECK (Rating >= 1 AND Rating <= 10),
#     ReviewText TEXT,
#     ReviewDate DATE,
#     NoiseLevel INT,
#     WifiQuality VARCHAR(50),
#     OutletAvailable BOOLEAN,
#     FOREIGN KEY (UserID) REFERENCES users(user_id),
#     FOREIGN KEY (SpotID) REFERENCES StudySpot(SpotID)
# );
#
# CREATE TABLE Photo (
#     PhotoID VARCHAR(50) PRIMARY KEY,
#     SpotID VARCHAR(50),
#     PhotoURL VARCHAR(255) NOT NULL,
#     UploadDate DATE,
#     Caption TEXT,
#     FOREIGN KEY (SpotID) REFERENCES StudySpot(SpotID)
# );
#
# CREATE TABLE Hours (
#     HoursID VARCHAR(50) PRIMARY KEY,
#     SpotID VARCHAR(50),
#     DayOfWeek VARCHAR(20) NOT NULL,
#     OpenTime TIME NOT NULL,
#     CloseTime TIME NOT NULL,
#     IsClosed BOOLEAN NOT NULL DEFAULT FALSE,
#     FOREIGN KEY (SpotID) REFERENCES StudySpot(SpotID)
# );
#
# CREATE TABLE Amenity (
#     AmenityID VARCHAR(50) PRIMARY KEY,
#     AmenityName VARCHAR(255)
# );
#
# CREATE TABLE Study_Spot_Amenity (
#     SpotID VARCHAR(50),
#     AmenityID VARCHAR(50),
#     PRIMARY KEY (SpotID, AmenityID),
#     FOREIGN KEY (SpotID) REFERENCES StudySpot(SpotID),
#     FOREIGN KEY (AmenityID) REFERENCES Amenity(AmenityID)
# );
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# ++
# ||
# ++
# ++

# %%
# %%sql
# SHOW TABLES;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 9 rows affected.
# +--------------------------------+
# | Tables_in_study_spots_database |
# +--------------------------------+
# |            Amenity             |
# |            category            |
# |             Hours              |
# |            Location            |
# |             Photo              |
# |             Review             |
# |       Study_Spot_Amenity       |
# |           StudySpot            |
# |             users              |
# +--------------------------------+

# %% [markdown]
# ## create.sql END
#
# now we will check the outputs of ```insert.sql```

# %%
# %%sql
# SELECT * FROM users;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 4 rows affected.
# +---------+--------------+--------------------+------------+-----------+---------------------+
# | user_id |   username   |       email        | first_name | last_name |       joinDate      |
# +---------+--------------+--------------------+------------+-----------+---------------------+
# |    1    |  study_pro   | ananya.k@email.com |   Ananya   |   Karthi  | 2026-01-15 00:00:00 |
# |    2    | coffee_lover | jairo.s@email.com  |   Jairo    |   Santos  | 2026-02-01 00:00:00 |
# |    3    | lib_finatic  | adonay.y@email.com |   Adonay   |   Yonnas  | 2026-02-10 00:00:00 |
# |    4    |  study_nerd  | chris.a@email.com  |   Chris    |  Alpuerto | 2026-02-15 00:00:00 |
# +---------+--------------+--------------------+------------+-----------+---------------------+

# %%
# %%sql
# INSERT INTO users (user_id, username, email, first_name, last_name, joinDate) VALUES
# (1, 'study_pro', 'ananya.k@email.com',  'Ananya', 'Karthi', '2026-01-15'),
# (2, 'coffee_lover', 'jairo.s@email.com', 'password2', 'Jairo', 'Santos', '2026-02-01'),
# (3, 'lib_finatic', 'adonay.y@email.com', 'password3', 'Adonay', 'Yonnas', '2026-02-10'),
# (4, 'study_nerd', 'chris.a@email.com', 'password4', 'Chris', 'Alpuerto', '2026-02-15');
#
# SELECT * FROM users;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 4 rows affected.
# 4 rows affected.
# +---------+--------------+--------------------+-----------+------------+-----------+---------------------+
# | user_id |   username   |       email        |  password | first_name | last_name |       joinDate      |
# +---------+--------------+--------------------+-----------+------------+-----------+---------------------+
# |    1    |  study_pro   | ananya.k@email.com | password1 |   Ananya   |   Karthi  | 2026-01-15 00:00:00 |
# |    2    | coffee_lover | jairo.s@email.com  | password2 |   Jairo    |   Santos  | 2026-02-01 00:00:00 |
# |    3    | lib_finatic  | adonay.y@email.com | password3 |   Adonay   |   Yonnas  | 2026-02-10 00:00:00 |
# |    4    |  study_nerd  | chris.a@email.com  | password4 |   Chris    |  Alpuerto | 2026-02-15 00:00:00 |
# +---------+--------------+--------------------+-----------+------------+-----------+---------------------+

# %%
# %%sql
# INSERT INTO Location (LocationID, Latitude, Longitude, StreetAddress, City, State, ZipCode) VALUES
# ('LOC001', '33.88135', '-117.88525', '800 State College Blvd', 'Fullerton', 'CA', 92834),
# ('LOC002', '33.87373', '-117.92417', '444 N Harbor Blvd', 'Fullerton', 'CA', 92832),
# ('LOC003', '33.78765', '-117.85372', '100 W Chapman Ave', 'Orange', 'CA', 92866);
# SELECT * FROM Location;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 3 rows affected.
# 3 rows affected.
# +------------+------------------------+-----------+-------+---------+------------+--------------+
# | LocationID |     StreetAddress      |    City   | State | ZipCode |  Latitude  |  Longitude   |
# +------------+------------------------+-----------+-------+---------+------------+--------------+
# |   LOC001   | 800 State College Blvd | Fullerton |   CA  |  92834  | 33.8813500 | -117.8852500 |
# |   LOC002   |   444 N Harbor Blvd    | Fullerton |   CA  |  92832  | 33.8737300 | -117.9241700 |
# |   LOC003   |   100 W Chapman Ave    |   Orange  |   CA  |  92866  | 33.7876500 | -117.8537200 |
# +------------+------------------------+-----------+-------+---------+------------+--------------+

# %%
# %%sql
# INSERT INTO Category (CategoryID, CategoryName) VALUES
# ('CAT01', 'Cafe'),
# ('CAT02', 'Library'),
# ('CAT03', 'Restaurant');
#
# INSERT INTO Amenity (AmenityID, AmenityName) VALUES
# ('AMEN01', 'Wi-Fi'),
# ('AMEN02', 'Power Outlets'),
# ('AMEN03', 'Indoor Seating'),
# ('AMEN04', 'Restrooms');
#
#
# INSERT INTO Hours (HoursID, SpotID, DayOfWeek, OpenTime, CloseTime, IsClosed) VALUES
# ('H001', 'SPOT01', 'Monday', '07:00:00', '22:00:00', FALSE),
# ('H002', 'SPOT01', 'Sunday', '00:00:00', '00:00:00', TRUE),
# ('H003', 'SPOT02', 'Monday', '07:00:00', '18:00:00', FALSE);
#
# -- Ratings are on a scale of 1-10
# INSERT INTO Review (ReviewID, UserID, SpotID, Rating, ReviewText, ReviewDate, NoiseLevel, WifiQuality, OutletAvailable) VALUES
# ('REV01', 1, 'SPOT03', 8, 'Great spot, but can get noisy during lunch.', '2026-03-01', 7, 'Good', FALSE),
# ('REV02', 2, 'SPOT02', 9, 'Great lattes and very reliable Wi-Fi.', '2026-03-05', 3, 'High Speed', TRUE),
# ('REV03', 3, 'SPOT01', 10, 'Silent and peaceful.', '2026-03-10', 1, 'Average', TRUE);
#
# INSERT INTO Photo (PhotoID, SpotID, PhotoURL, UploadDate, Caption) VALUES
# ('PH01', 'SPOT01', '', '2026-03-01', 'Quietest study spot in the library'),
# ('PH02', 'SPOT02', '', '2026-03-05', 'Seat with outlet available');
#
# INSERT INTO Study_Spot_Amenity (SpotID, AmenityID) VALUES
# ('SPOT01', 'AMEN01'), -- Pollak Library has Wi-Fi
# ('SPOT01', 'AMEN02'), -- Pollak Library has Outlets
# ('SPOT02', 'AMEN01'), -- Lovetta has Wi-Fi
# ('SPOT02', 'AMEN03'), -- Lovetta has indoor Seating
# ('SPOT03', 'AMEN04'); -- Urth Caffe has Restrooms
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 3 rows affected.
# 4 rows affected.
# RuntimeError: (pymysql.err.OperationalError) (1054, "Unknown column 'PhoneNum' in 'field list'")
# [SQL: INSERT INTO StudySpot (SpotID, SpotName, Description, Website, PhoneNum, PriceLevel, CategoryID, LocationID) VALUES
# ('SPOT01', 'Pollak Library', 'Central library at CSUF with plenty of tables and outlets.', 'library.fullerton.edu', 7142782011, 0.0, 'CAT01', 'LOC001'),
# ('SPOT02', 'Lovetta', 'Cozy local cafe with great espresso.', 'lovetta-fullerton.square.site', 7145193130, 1.0, 'CAT02', 'LOC002'),
# ('SPOT03', 'Urth Caffe', 'Breakfast and lunch spot with a cozy atmosphere.', 'urthcaffe.com', 9493295755, 3.0, 'CAT03', 'LOC003');]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# ALTER TABLE StudySpot
# DROP COLUMN location;
# SELECT * FROM StudySpot;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# +--------+----------+-------------+---------+-------------+------------+------------+------------+----------+
# | SpotID | spotName | Description | Website | phoneNumber | PriceLevel | CategoryID | LocationID | PhoneNum |
# +--------+----------+-------------+---------+-------------+------------+------------+------------+----------+
# +--------+----------+-------------+---------+-------------+------------+------------+------------+----------+

# %%
# %%sql
#
# INSERT INTO StudySpot (SpotID, SpotName, Description, Website, PhoneNum, PriceLevel, CategoryID, LocationID) VALUES
# ('SPOT01', 'Pollak Library', 'Central library at CSUF with plenty of tables and outlets.', 'library.fullerton.edu', 7142782011, 0.0, 'CAT01', 'LOC001'),
# ('SPOT02', 'Lovetta', 'Cozy local cafe with great espresso.', 'lovetta-fullerton.square.site', 7145193130, 1.0, 'CAT02', 'LOC002'),
# ('SPOT03', 'Urth Caffe', 'Breakfast and lunch spot with a cozy atmosphere.', 'urthcaffe.com', 9493295755, 3.0, 'CAT03', 'LOC003');
#
# SELECT * FROM StudySpot;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 3 rows affected.
# 3 rows affected.
# +--------+----------------+------------------------------------------------------------+-------------------------------+-------------+------------+------------+------------+------------+
# | SpotID |    spotName    |                        Description                         |            Website            | phoneNumber | PriceLevel | CategoryID | LocationID |  PhoneNum  |
# +--------+----------------+------------------------------------------------------------+-------------------------------+-------------+------------+------------+------------+------------+
# | SPOT01 | Pollak Library | Central library at CSUF with plenty of tables and outlets. |     library.fullerton.edu     |     None    |    0.0     |   CAT01    |   LOC001   | 7142782011 |
# | SPOT02 |    Lovetta     |            Cozy local cafe with great espresso.            | lovetta-fullerton.square.site |     None    |    1.0     |   CAT02    |   LOC002   | 7145193130 |
# | SPOT03 |   Urth Caffe   |      Breakfast and lunch spot with a cozy atmosphere.      |         urthcaffe.com         |     None    |    3.0     |   CAT03    |   LOC003   | 9493295755 |
# +--------+----------------+------------------------------------------------------------+-------------------------------+-------------+------------+------------+------------+------------+

# %%
# %%sql
# INSERT INTO Hours (HoursID, SpotID, DayOfWeek, OpenTime, CloseTime, IsClosed) VALUES
# ('H001', 'SPOT01', 'Monday', '07:00:00', '22:00:00', FALSE),
# ('H002', 'SPOT01', 'Sunday', '00:00:00', '00:00:00', TRUE),
# ('H003', 'SPOT02', 'Monday', '07:00:00', '18:00:00', FALSE);
#
# -- Ratings are on a scale of 1-10
# INSERT INTO Review (ReviewID, UserID, SpotID, Rating, ReviewText, ReviewDate, NoiseLevel, WifiQuality, OutletAvailable) VALUES
# ('REV01', 1, 'SPOT03', 8, 'Great spot, but can get noisy during lunch.', '2026-03-01', 7, 'Good', FALSE),
# ('REV02', 2, 'SPOT02', 9, 'Great lattes and very reliable Wi-Fi.', '2026-03-05', 3, 'High Speed', TRUE),
# ('REV03', 3, 'SPOT01', 10, 'Silent and peaceful.', '2026-03-10', 1, 'Average', TRUE);
#
# INSERT INTO Photo (PhotoID, SpotID, PhotoURL, UploadDate, Caption) VALUES
# ('PH01', 'SPOT01', '', '2026-03-01', 'Quietest study spot in the library'),
# ('PH02', 'SPOT02', '', '2026-03-05', 'Seat with outlet available');
#
# INSERT INTO Study_Spot_Amenity (SpotID, AmenityID) VALUES
# ('SPOT01', 'AMEN01'), -- Pollak Library has Wi-Fi
# ('SPOT01', 'AMEN02'), -- Pollak Library has Outlets
# ('SPOT02', 'AMEN01'), -- Lovetta has Wi-Fi
# ('SPOT02', 'AMEN03'), -- Lovetta has indoor Seating
# ('SPOT03', 'AMEN04'); -- Urth Caffe has Restrooms
# SELECT * FROM Hours;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 3 rows affected.
# 3 rows affected.
# 2 rows affected.
# 5 rows affected.
# 3 rows affected.
# +---------+--------+-----------+----------+-----------+----------+
# | HoursID | SpotID | DayOfWeek | OpenTime | CloseTime | IsClosed |
# +---------+--------+-----------+----------+-----------+----------+
# |   H001  | SPOT01 |   Monday  | 7:00:00  |  22:00:00 |    0     |
# |   H002  | SPOT01 |   Sunday  | 0:00:00  |  0:00:00  |    1     |
# |   H003  | SPOT02 |   Monday  | 7:00:00  |  18:00:00 |    0     |
# +---------+--------+-----------+----------+-----------+----------+

# %% [markdown]
# ## FINISH insert.sql
# Below, we will check if the tables contain the correct information
#
# SELECT * FROM users;
# SELECT * FROM Category;
# SELECT * FROM Amenity;
# SELECT * FROM StudySpot;
# SELECT * FROM Review;
# SELECT * FROM Photo;
# SELECT * FROM Study_Spot_Amenity;
# SELECT * FROM Hours;

# %%
# %%sql
# SELECT * FROM users;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 4 rows affected.
# 3 rows affected.
# +------------+------------------------+-----------+-------+---------+------------+--------------+
# | LocationID |     StreetAddress      |    City   | State | ZipCode |  Latitude  |  Longitude   |
# +------------+------------------------+-----------+-------+---------+------------+--------------+
# |   LOC001   | 800 State College Blvd | Fullerton |   CA  |  92834  | 33.8813500 | -117.8852500 |
# |   LOC002   |   444 N Harbor Blvd    | Fullerton |   CA  |  92832  | 33.8737300 | -117.9241700 |
# |   LOC003   |   100 W Chapman Ave    |   Orange  |   CA  |  92866  | 33.7876500 | -117.8537200 |
# +------------+------------------------+-----------+-------+---------+------------+--------------+

# %%
# %%sql
# SHOW TABLES;
# SELECT * FROM StudySpot;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 9 rows affected.
# 3 rows affected.
# +--------+----------------+------------------------------------------------------------+-------------------------------+-------------+------------+------------+------------+------------+
# | SpotID |    spotName    |                        Description                         |            Website            | phoneNumber | PriceLevel | CategoryID | LocationID |  PhoneNum  |
# +--------+----------------+------------------------------------------------------------+-------------------------------+-------------+------------+------------+------------+------------+
# | SPOT01 | Pollak Library | Central library at CSUF with plenty of tables and outlets. |     library.fullerton.edu     |     None    |    0.0     |   CAT01    |   LOC001   | 7142782011 |
# | SPOT02 |    Lovetta     |            Cozy local cafe with great espresso.            | lovetta-fullerton.square.site |     None    |    1.0     |   CAT02    |   LOC002   | 7145193130 |
# | SPOT03 |   Urth Caffe   |      Breakfast and lunch spot with a cozy atmosphere.      |         urthcaffe.com         |     None    |    3.0     |   CAT03    |   LOC003   | 9493295755 |
# +--------+----------------+------------------------------------------------------------+-------------------------------+-------------+------------+------------+------------+------------+

# %% [markdown]
# ## START QUERIES.SQL
# testing create.sql files
# - SET 1: Discovery and search (user use cases)
# Below is Query 1

# %% [markdown]
# Query 1 set 1: find all study spots in a specific city (Fullerton)

# %%
# %%sql
# SELECT s.spotName, l.StreetAddress, l.City
# FROM StudySpot s
# JOIN Location l ON s.LocationID = l.LocationID
# WHERE l.City = 'Fullerton';
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 2 rows affected.
# +----------------+------------------------+-----------+
# |    spotName    |     StreetAddress      |    City   |
# +----------------+------------------------+-----------+
# | Pollak Library | 800 State College Blvd | Fullerton |
# |    Lovetta     |   444 N Harbor Blvd    | Fullerton |
# +----------------+------------------------+-----------+

# %% [markdown]
# Query 2 Set 1:
# find study spots that offer wifi

# %%
# %%sql
# SELECT s.spotName
# FROM StudySpot s
# JOIN Study_Spot_Amenity ssa ON s.SpotID = ssa.SpotID
# JOIN Amenity a ON ssa.AmenityID = a.AmenityID
# WHERE a.AmenityName = 'Wi-Fi';
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 2 rows affected.
# +----------------+
# |    spotName    |
# +----------------+
# | Pollak Library |
# |    Lovetta     |
# +----------------+

# %% [markdown]
# Query 3 set 1: identify spots open on a specific day

# %%
# %%sql
# SELECT s.spotName, h.OpenTime, h.CloseTime
# FROM StudySpot s
# JOIN Hours h ON s.SpotID = h.SpotID
# WHERE h.DayOfWeek = 'Monday' AND h.isClosed = FALSE;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 2 rows affected.
# +----------------+----------+-----------+
# |    spotName    | OpenTime | CloseTime |
# +----------------+----------+-----------+
# | Pollak Library | 7:00:00  |  22:00:00 |
# |    Lovetta     | 7:00:00  |  18:00:00 |
# +----------------+----------+-----------+

# %% [markdown]
# ### SET 2: Social and feedback (community use cases)
# query 1 set 2: calculate avg rating for each study spot

# %%
# %%sql
# SELECT s.spotName, AVG(r.Rating) AS Average_Rating
# FROM StudySpot s
# JOIN Review r ON s.SpotID = r.SpotID
# GROUP BY s.spotName;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 3 rows affected.
# +----------------+----------------+
# |    spotName    | Average_Rating |
# +----------------+----------------+
# | Pollak Library |    10.0000     |
# |    Lovetta     |     9.0000     |
# |   Urth Caffe   |     8.0000     |
# +----------------+----------------+

# %% [markdown]
# query 2 set 2: retrieve all reviews for a spot with the reviewer's username

# %%
# %%sql
# SELECT u.username, r.Rating, r.ReviewText, r.ReviewDate
# FROM Review r
# JOIN users u ON r.userID = u.user_id
# JOIN StudySpot s ON r.SpotID = s.SpotID
# WHERE s.SpotName = 'Lovetta';
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 1 rows affected.
# +--------------+--------+---------------------------------------+------------+
# |   username   | Rating |               ReviewText              | ReviewDate |
# +--------------+--------+---------------------------------------+------------+
# | coffee_lover |   9    | Great lattes and very reliable Wi-Fi. | 2026-03-05 |
# +--------------+--------+---------------------------------------+------------+

# %% [markdown]
# query 3 set 2:list all photos uploaded for a specific spot

# %%
# %%sql
# SELECT p.PhotoURL, p.Caption, p.UploadDate
# FROM Photo p
# JOIN StudySpot s ON p.SpotID = s.SpotID
# WHERE s.SpotName = 'Pollak Library';
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/cpsc332_group_project'
# 1 rows affected.
# +----------+------------------------------------+------------+
# | PhotoURL |              Caption               | UploadDate |
# +----------+------------------------------------+------------+
# |          | Quietest study spot in the library | 2026-03-01 |
# +----------+------------------------------------+------------+

# %% [markdown]
# # QUERIES.SQL FIN and sql file run finish
# Mainly used this to record output history
